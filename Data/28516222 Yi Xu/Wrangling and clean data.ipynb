# %%
import pandas as pd
import numpy as np

# %%
dataSuiside = pd.read_csv("./WHOSuicideData.csv")

# %%
dataSuiside
# Out:
#       Unnamed: 0  Unnamed: 1  \
# 0        Country         Sex
# 1    Afghanistan  Both sexes
# 2    Afghanistan        Male
# 3    Afghanistan      Female
# 4        Albania  Both sexes
# ..           ...         ...
# 545       Zambia        Male
# 546       Zambia      Female
# 547     Zimbabwe  Both sexes
# 548     Zimbabwe        Male
# 549     Zimbabwe      Female
#
#      Age-standardized suicide rates (per 100 000 population)  \
# 0                                               2016.0
# 1                                                  6.4
# 2                                                 10.6
# 3                                                  2.1
# 4                                                  5.6
# ..                                                 ...
# 545                                               17.5
# 546                                                6.2
# 547                                               19.1
# ...

# %% [markdown]
# # Change the column name

# %%
dataSuiside.rename(columns = {'Unnamed: 0' : 'Country','Unnamed: 1' : 'Sex'},inplace = True)

# %%
dataSuiside.rename(columns = {'Age-standardized suicide rates (per 100 000 population)' : '2016','Age-standardized suicide rates (per 100 000 population).1' : '2015'},inplace = True)

# %%
dataSuiside.rename(columns = {'Age-standardized suicide rates (per 100 000 population).2' : '2010','Age-standardized suicide rates (per 100 000 population).3' : '2000'},inplace = True)

# %%
dataSuiside
# Out:
#          Country         Sex    2016    2015    2010    2000
# 0        Country         Sex  2016.0  2015.0  2010.0  2000.0
# 1    Afghanistan  Both sexes     6.4     6.6     7.4     8.1
# 2    Afghanistan        Male    10.6    10.9    12.5    14.3
# 3    Afghanistan      Female     2.1     2.1     2.1     1.7
# 4        Albania  Both sexes     5.6     5.3     7.7     5.8
# ..           ...         ...     ...     ...     ...     ...
# 545       Zambia        Male    17.5    17.4    17.9    21.9
# 546       Zambia      Female     6.2     6.1     6.2     7.5
# 547     Zimbabwe  Both sexes    19.1    18.9    20.6    21.7
# 548     Zimbabwe        Male    29.1    28.7    32.3    35.5
# 549     Zimbabwe      Female    11.1    11.1    11.1     9.8
#
# [550 rows x 6 columns]

# %% [markdown]
# # Delete the first row

# %%
data2 = dataSuiside.drop([0], axis=0,inplace = True)

# %%
dataSuiside
# Out:
#          Country         Sex  2016  2015  2010  2000
# 1    Afghanistan  Both sexes   6.4   6.6   7.4   8.1
# 2    Afghanistan        Male  10.6  10.9  12.5  14.3
# 3    Afghanistan      Female   2.1   2.1   2.1   1.7
# 4        Albania  Both sexes   5.6   5.3   7.7   5.8
# 5        Albania        Male   7.0   6.7   9.5   8.2
# ..           ...         ...   ...   ...   ...   ...
# 545       Zambia        Male  17.5  17.4  17.9  21.9
# 546       Zambia      Female   6.2   6.1   6.2   7.5
# 547     Zimbabwe  Both sexes  19.1  18.9  20.6  21.7
# 548     Zimbabwe        Male  29.1  28.7  32.3  35.5
# 549     Zimbabwe      Female  11.1  11.1  11.1   9.8
#
# [549 rows x 6 columns]

# %% [markdown]
# # convert columns(2016,2015,2010,2000) into rows

# %%
dataNew = dataSuiside.melt(id_vars=["Country", "Sex"], 
        var_name="Year", 
        value_name="Suicide Rates/100k population")

# %%
dataNew
# Out:
#           Country         Sex  Year  Suicide Rates/100k population
# 0     Afghanistan  Both sexes  2016                            6.4
# 1     Afghanistan        Male  2016                           10.6
# 2     Afghanistan      Female  2016                            2.1
# 3         Albania  Both sexes  2016                            5.6
# 4         Albania        Male  2016                            7.0
# ...           ...         ...   ...                            ...
# 2191       Zambia        Male  2000                           21.9
# 2192       Zambia      Female  2000                            7.5
# 2193     Zimbabwe  Both sexes  2000                           21.7
# 2194     Zimbabwe        Male  2000                           35.5
# 2195     Zimbabwe      Female  2000                            9.8
#
# [2196 rows x 4 columns]

# %% [markdown]
# # Oeder data frame by column(Country and Year)

# %%
dataSuiside = dataNew.sort_values(["Country", "Year"])

# %%
dataSuiside
# Out:
#           Country         Sex  Year  Suicide Rates/100k population
# 1647  Afghanistan  Both sexes  2000                            8.1
# 1648  Afghanistan        Male  2000                           14.3
# 1649  Afghanistan      Female  2000                            1.7
# 1098  Afghanistan  Both sexes  2010                            7.4
# 1099  Afghanistan        Male  2010                           12.5
# ...           ...         ...   ...                            ...
# 1096     Zimbabwe        Male  2015                           28.7
# 1097     Zimbabwe      Female  2015                           11.1
# 546      Zimbabwe  Both sexes  2016                           19.1
# 547      Zimbabwe        Male  2016                           29.1
# 548      Zimbabwe      Female  2016                           11.1
#
# [2196 rows x 4 columns]

# %% [markdown]
# # Change the order of columns

# %%
dataSuiside = dataSuiside[['Country', 'Year', 'Sex', 'Suicide Rates/100k population']]

# %%
dataSuiside
# Out:
#           Country  Year         Sex  Suicide Rates/100k population
# 1647  Afghanistan  2000  Both sexes                            8.1
# 1648  Afghanistan  2000        Male                           14.3
# 1649  Afghanistan  2000      Female                            1.7
# 1098  Afghanistan  2010  Both sexes                            7.4
# 1099  Afghanistan  2010        Male                           12.5
# ...           ...   ...         ...                            ...
# 1096     Zimbabwe  2015        Male                           28.7
# 1097     Zimbabwe  2015      Female                           11.1
# 546      Zimbabwe  2016  Both sexes                           19.1
# 547      Zimbabwe  2016        Male                           29.1
# 548      Zimbabwe  2016      Female                           11.1
#
# [2196 rows x 4 columns]

# %%
dataSuiside.dtypes
# Out:
# Country                           object
# Year                              object
# Sex                               object
# Suicide Rates/100k population    float64
# dtype: object

# %% [markdown]
# # Add new dataframe

# %%
dataWorldwideGDP = pd.read_csv("./API_NY.GDP.MKTP.csv")

# %%
dataWorldwideGDP
# Out:
#            Data Source World Development Indicators         Unnamed: 2  \
# 0                  NaN                          NaN                NaN
# 1    Last Updated Date                    3/18/2020                NaN
# 2                  NaN                          NaN                NaN
# 3         Country Name                 Country Code     Indicator Name
# 4                Aruba                          ABW  GDP (current US$)
# ..                 ...                          ...                ...
# 263             Kosovo                          XKX  GDP (current US$)
# 264        Yemen, Rep.                          YEM  GDP (current US$)
# 265       South Africa                          ZAF  GDP (current US$)
# 266             Zambia                          ZMB  GDP (current US$)
# 267           Zimbabwe                          ZWE  GDP (current US$)
#
#          Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# ...

# %% [markdown]
# # Delete the row

# %%
data3 = dataWorldwideGDP.drop([0,1,2], axis=0,inplace = True)

# %%
dataWorldwideGDP
# Out:
#       Data Source World Development Indicators         Unnamed: 2  \
# 3    Country Name                 Country Code     Indicator Name
# 4           Aruba                          ABW  GDP (current US$)
# 5     Afghanistan                          AFG  GDP (current US$)
# 6          Angola                          AGO  GDP (current US$)
# 7         Albania                          ALB  GDP (current US$)
# ..            ...                          ...                ...
# 263        Kosovo                          XKX  GDP (current US$)
# 264   Yemen, Rep.                          YEM  GDP (current US$)
# 265  South Africa                          ZAF  GDP (current US$)
# 266        Zambia                          ZMB  GDP (current US$)
# 267      Zimbabwe                          ZWE  GDP (current US$)
#
#          Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# 3    Indicator Code  1.960000e+03  1.961000e+03  1.962000e+03  1.963000e+03
# ...

# %%
dataWorldwideGDP.drop(dataWorldwideGDP.iloc[:,4:42],1,inplace=True)

# %%
dataWorldwideGDP.drop(dataWorldwideGDP.iloc[:,2:5],1,inplace=True)

# %%
dataWorldwideGDP.drop('Unnamed: 43',1,inplace=True)

# %%
dataWorldwideGDP.drop(dataWorldwideGDP.iloc[:,3:11],1,inplace=True)

# %%
dataWorldwideGDP
# Out:
#       Data Source World Development Indicators   Unnamed: 44   Unnamed: 53  \
# 3    Country Name                 Country Code  2.000000e+03  2.009000e+03
# 4           Aruba                          ABW  1.873453e+09  2.498883e+09
# 5     Afghanistan                          AFG           NaN  1.243909e+10
# 6          Angola                          AGO  9.129595e+09  7.030716e+10
# 7         Albania                          ALB  3.480355e+09  1.204422e+10
# ..            ...                          ...           ...           ...
# 263        Kosovo                          XKX  1.849196e+09  5.653823e+09
# 264   Yemen, Rep.                          YEM  9.652436e+09  2.513027e+10
# 265  South Africa                          ZAF  1.363610e+11  2.959360e+11
# 266        Zambia                          ZMB  3.600683e+09  1.532834e+10
# 267      Zimbabwe                          ZWE  6.689958e+09  9.665793e+09
#
# ...

# %% [markdown]
# # Change the column name

# %%
dataWorldwideGDP.rename(columns = {'Unnamed: 44' : '2000','Unnamed: 53' : '2009','Unnamed: 54' : '2010','Unnamed: 55' : '2011','Unnamed: 56' : '2012','Unnamed: 57' : '2013','Unnamed: 58' : '2014','Unnamed: 59' : '2015','Unnamed: 60' : '2016','Unnamed: 61' : '2017','Unnamed: 62' : '2018','Unnamed: 63' : '2019'},inplace = True)

# %%
dataWorldwideGDP.rename(columns = {'Data Source' : 'Country','World Development Indicators' : 'Country Code'},inplace = True)

# %%
data3 = dataWorldwideGDP.drop([3], axis=0,inplace = True)

# %%
dataWorldwideGDP
# Out:
#           Country Country Code          2000          2009          2010  \
# 4           Aruba          ABW  1.873453e+09  2.498883e+09  2.390503e+09
# 5     Afghanistan          AFG           NaN  1.243909e+10  1.585657e+10
# 6          Angola          AGO  9.129595e+09  7.030716e+10  8.379950e+10
# 7         Albania          ALB  3.480355e+09  1.204422e+10  1.192696e+10
# 8         Andorra          AND  1.434430e+09  3.660531e+09  3.355695e+09
# ..            ...          ...           ...           ...           ...
# 263        Kosovo          XKX  1.849196e+09  5.653823e+09  5.830416e+09
# 264   Yemen, Rep.          YEM  9.652436e+09  2.513027e+10  3.090675e+10
# 265  South Africa          ZAF  1.363610e+11  2.959360e+11  3.753490e+11
# 266        Zambia          ZMB  3.600683e+09  1.532834e+10  2.026556e+10
# 267      Zimbabwe          ZWE  6.689958e+09  9.665793e+09  1.204166e+10
#
#              2011          2012          2013          2014          2015  \
# ...

# %%
dataWorldwideGDP.drop(['2019'],1,inplace=True)

# %%
dataWorldwideGDP
# Out:
#           Country Country Code          2000          2009          2010  \
# 4           Aruba          ABW  1.873453e+09  2.498883e+09  2.390503e+09
# 5     Afghanistan          AFG           NaN  1.243909e+10  1.585657e+10
# 6          Angola          AGO  9.129595e+09  7.030716e+10  8.379950e+10
# 7         Albania          ALB  3.480355e+09  1.204422e+10  1.192696e+10
# 8         Andorra          AND  1.434430e+09  3.660531e+09  3.355695e+09
# ..            ...          ...           ...           ...           ...
# 263        Kosovo          XKX  1.849196e+09  5.653823e+09  5.830416e+09
# 264   Yemen, Rep.          YEM  9.652436e+09  2.513027e+10  3.090675e+10
# 265  South Africa          ZAF  1.363610e+11  2.959360e+11  3.753490e+11
# 266        Zambia          ZMB  3.600683e+09  1.532834e+10  2.026556e+10
# 267      Zimbabwe          ZWE  6.689958e+09  9.665793e+09  1.204166e+10
#
#              2011          2012          2013          2014          2015  \
# ...

# %% [markdown]
# # convert columns(2010-2018) into rows

# %%
dataNew2 = dataWorldwideGDP.melt(id_vars=["Country", "Country Code"], 
        var_name="Year", 
        value_name="GDP_for_year ($) ")

# %%
dataNew2
# Out:
#            Country Country Code  Year  GDP_for_year ($)
# 0            Aruba          ABW  2000       1.873453e+09
# 1      Afghanistan          AFG  2000                NaN
# 2           Angola          AGO  2000       9.129595e+09
# 3          Albania          ALB  2000       3.480355e+09
# 4          Andorra          AND  2000       1.434430e+09
# ...            ...          ...   ...                ...
# 2899        Kosovo          XKX  2018       7.938991e+09
# 2900   Yemen, Rep.          YEM  2018       2.691440e+10
# 2901  South Africa          ZAF  2018       3.682890e+11
# 2902        Zambia          ZMB  2018       2.672007e+10
# 2903      Zimbabwe          ZWE  2018       3.100052e+10
#
# [2904 rows x 4 columns]

# %% [markdown]
# # Order the data frame by column(Country and Year)

# %%
dataWorldwideGDP = dataNew2.sort_values(["Country", "Year"])

# %%
dataWorldwideGDP
# Out:
#           Country Country Code  Year  GDP_for_year ($)
# 1     Afghanistan          AFG  2000                NaN
# 265   Afghanistan          AFG  2009       1.243909e+10
# 529   Afghanistan          AFG  2010       1.585657e+10
# 793   Afghanistan          AFG  2011       1.780428e+10
# 1057  Afghanistan          AFG  2012       2.000162e+10
# ...           ...          ...   ...                ...
# 1847     Zimbabwe          ZWE  2014       1.949552e+10
# 2111     Zimbabwe          ZWE  2015       1.996312e+10
# 2375     Zimbabwe          ZWE  2016       2.054868e+10
# 2639     Zimbabwe          ZWE  2017       2.281301e+10
# 2903     Zimbabwe          ZWE  2018       3.100052e+10
#
# [2904 rows x 4 columns]

# %%
dataSuiside.to_csv("./CLEANdataSuiside.csv")

# %%
dataWorldwideGDP.to_csv("./CLEANdataWorldwideGDP.csv")

# %% [markdown]
# # Combine two DataFrames using Year

# %%
GDPdata = pd.read_csv("./dataWorldwideGDP1.csv")

# %%
dataSuiside = read("./CLEANdataSuiside.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9f513ec8aa8b> in <module>
# ----> 1 dataSuiside = read("./CLEANdataSuiside.csv")
#
# NameError: name 'read' is not defined

# %% [markdown]
# # Combine two DataFrames using Country and Year

# %%
dataSuiside.dtypes
# Out:
# Country     object
# Sex         object
# 2016       float64
# 2015       float64
# 2010       float64
# 2000       float64
# dtype: object

# %%
GDPdata.dtypes
# Out:
# Unnamed: 0             int64
# Country               object
# Country Code          object
# Year                  object
# GDP_for_year ($)     float64
# year                  object
# dtype: object

# %%
GDPdata["Year"] = GDPdata["Year"].astype('str')

# %%
dataCombine = pd.merge(dataSuiside,GDPdata,how = "left", on = ["Country","Year"])

# %% [markdown]
# # DATA CHECKING (Check the null value)

# %%
dataCombine.isnull().sum().sort_values(ascending = False)
# Out:
# GDP_for_year ($)                 90
# year                             36
# Country Code                     36
# Unnamed: 0                       36
# Suicide Rates/100k population     0
# Sex                               0
# Year                              0
# Country                           0
# dtype: int64

# %%
res = dataCombine[dataCombine['GDP_for_year ($) '].isnull() == True]

# %%
res
# Out:
#                                  Country  Year         Sex  \
# 0                            Afghanistan  2000  Both sexes
# 1                            Afghanistan  2000        Male
# 2                            Afghanistan  2000      Female
# 324                       C??te d'Ivoire  2000  Both sexes
# 325                       C??te d'Ivoire  2000        Male
# ...                                  ...   ...         ...
# 2143  Venezuela (Bolivarian Republic of)  2015        Male
# 2144  Venezuela (Bolivarian Republic of)  2015      Female
# 2145  Venezuela (Bolivarian Republic of)  2016  Both sexes
# 2146  Venezuela (Bolivarian Republic of)  2016        Male
# 2147  Venezuela (Bolivarian Republic of)  2016      Female
#
#       Suicide Rates/100k population  Unnamed: 0 Country Code  \
# 0                               8.1         1.0          AFG
# 1                              14.3         1.0          AFG
# 2                               1.7         1.0          AFG
# ...

# %%
res.to_csv("./res.csv")

# %%
import pandas as pd

# %%
df = pd.read_csv("res.csv")

# %%
pd.set_option('display.max_rows', df.shape[0]+1)

# %% [markdown]
# # DATA CHECKING (Addressing null values)

# %%
print(df)
# Out:
#     Unnamed: 0                                Country  Year         Sex  \
# 0            0                            Afghanistan  2000  Both sexes
# 1            1                            Afghanistan  2000        Male
# 2            2                            Afghanistan  2000      Female
# 3          324                         C??te d'Ivoire  2000  Both sexes
# 4          325                         C??te d'Ivoire  2000        Male
# 5          326                         C??te d'Ivoire  2000      Female
# 6          327                         C??te d'Ivoire  2010  Both sexes
# 7          328                         C??te d'Ivoire  2010        Male
# 8          329                         C??te d'Ivoire  2010      Female
# 9          330                         C??te d'Ivoire  2015  Both sexes
# 10         331                         C??te d'Ivoire  2015        Male
# 11         332                         C??te d'Ivoire  2015      Female
# ...

# %%
dataCombine.loc[[0,1,2], 'GDP_for_year ($) '] = '1903000000'

# %%
pd.set_option('display.max_rows', dataCombine.shape[0]+1)

# %%
dataCombine.drop([324,325,326,327,328,329,330,331,332,333,334,335],axis = 0,inplace = False)

# %%
dataCombine.drop([324,325,326,327,328,329,330,331,332,333,334,335],axis = 0,inplace = False)
# Out:
#                                                 Country  Year         Sex  \
# 0                                           Afghanistan  2000  Both sexes
# 1                                           Afghanistan  2000        Male
# 2                                           Afghanistan  2000      Female
# 3                                           Afghanistan  2010  Both sexes
# 4                                           Afghanistan  2010        Male
# 5                                           Afghanistan  2010      Female
# 6                                           Afghanistan  2015  Both sexes
# 7                                           Afghanistan  2015        Male
# 8                                           Afghanistan  2015      Female
# 9                                           Afghanistan  2016  Both sexes
# 10                                          Afghanistan  2016        Male
# 11                                          Afghanistan  2016      Female
# ...

# %%
dataCombine.loc[[516,517,518], 'GDP_for_year ($) '] = '61650000000'

# %%
dataCombine.loc[[519,520,521], 'GDP_for_year ($) '] = '207500000000'

# %%
dataCombine.loc[[522,523,524], 'GDP_for_year ($) '] = '186800000000'

# %%
dataCombine.loc[[525,526,527], 'GDP_for_year ($) '] = '195100000000'

# %%
dataCombine.loc[[528,529,530], 'GDP_for_year ($) '] = '14025916926'

# %%
dataCombine.loc[[531,532,533], 'GDP_for_year ($) '] = '15793672444'

# %%
dataCombine.loc[[534,535,536], 'GDP_for_year ($) '] = '16282601357'

# %%
dataCombine.loc[[537,538,539], 'GDP_for_year ($) '] = '16912500367'

# %%
dataCombine.loc[[642,643,644], 'GDP_for_year ($) '] = '2010000000'

# %%
dataCombine.loc[[645,646,647], 'GDP_for_year ($) '] = '2210000000'

# %%
dataCombine.loc[[936,937,938], 'GDP_for_year ($) '] = '25857000000'

# %%
dataCombine.loc[[1680,1681,1682], 'GDP_for_year ($) '] = '77000000'

# %%
dataCombine.loc[[1764,1765,1766], 'GDP_for_year ($) '] = '29170000000'

# %%
dataCombine.loc[[1767,1768,1769], 'GDP_for_year ($) '] = '90180000000'

# %%
dataCombine.loc[[1770,1771,1772], 'GDP_for_year ($) '] = '88460000000'

# %%
dataCombine.loc[[1773,1774,1775], 'GDP_for_year ($) '] = '89640000000'

# %%
dataCombine.loc[[1800,1801,1802], 'GDP_for_year ($) '] = '2052000000'

# %%
dataCombine.loc[[1803,1804,1805], 'GDP_for_year ($) '] = '1903000000'

# %%
dataCombine.loc[[1824,1825,1826], 'GDP_for_year ($) '] = '10682000000'

# %%
dataCombine.loc[[1833,1834,1835], 'GDP_for_year ($) '] = '95558000000'

# %%
dataCombine.loc[[1911,1912,1913], 'GDP_for_year ($) '] = '60043000000'

# %%
dataCombine.loc[[1914,1915,1916], 'GDP_for_year ($) '] = '19090000000'

# %%
dataCombine.loc[[1917,1918,1919], 'GDP_for_year ($) '] = '12377000000'

# %%
dataCombine.loc[[2142,2143,2144], 'GDP_for_year ($) '] = '323600000000'

# %%
dataCombine.loc[[2145,2146,2147], 'GDP_for_year ($) '] = '279250000000'

# %%
dataCombine.isnull().sum().sort_values(ascending = False)
# Out:
# year                             36
# Country Code                     36
# Unnamed: 0                       36
# GDP_for_year ($)                 12
# Suicide Rates/100k population     0
# Sex                               0
# Year                              0
# Country                           0
# dtype: int64

# %%
res = dataCombine[dataCombine['GDP_for_year ($) '].isnull() == True]

# %%
res
# Out:
#             Country  Year         Sex  Suicide Rates/100k population  \
# 324  C??te d'Ivoire  2000  Both sexes                           16.5
# 325  C??te d'Ivoire  2000        Male                           23.1
# 326  C??te d'Ivoire  2000      Female                            9.1
# 327  C??te d'Ivoire  2010  Both sexes                           20.7
# 328  C??te d'Ivoire  2010        Male                           29.1
# 329  C??te d'Ivoire  2010      Female                           11.4
# 330  C??te d'Ivoire  2015  Both sexes                           22.8
# 331  C??te d'Ivoire  2015        Male                           31.9
# 332  C??te d'Ivoire  2015      Female                           12.9
# 333  C??te d'Ivoire  2016  Both sexes                           23.0
# 334  C??te d'Ivoire  2016        Male                           32.0
# 335  C??te d'Ivoire  2016      Female                           13.0
#
#      Unnamed: 0 Country Code GDP_for_year ($)  year
# ...

# %%
dataCombine.dropna(axis=0, how="any",inplace=True)

# %%
dataCombine.isnull().sum().sort_values(ascending = False)
# Out:
# year                             0
# GDP_for_year ($)                 0
# Country Code                     0
# Unnamed: 0                       0
# Suicide Rates/100k population    0
# Sex                              0
# Year                             0
# Country                          0
# dtype: int64

# %%
dataCombine.to_csv("./DATACLEANNULLVALUE.csv")

# %%
dataCombine = pd.read_csv("./DATACLEANNULLVALUE.csv")

# %% [markdown]
# # DATACHECKING(Check for duplicates)

# %%
dup = dataCombine[dataCombine.duplicated()]

# %%
dup
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Country, Year, Sex, Suicide Rates/100k population, Unnamed: 0.1, Country Code, GDP_for_year ($) , year]
# Index: []

# %% [markdown]
# # DATACHECKING(Check if the data is logical)

# %%
SuicideLogical = dataCombine[dataCombine.loc[:, 'Suicide Rates/100k population'] < 0]

# %%
SuicideLogical
# Out:
# Empty DataFrame
# Columns: [Country, Country Code, Year, Sex, Suicide Rates/100k population, GDP_for_year ($) ]
# Index: []

# %%
GDPLogical = dataCombine[dataCombine.loc[:, 'GDP_for_year ($) '] < 0]

# %%
GDPLogical
# Out:
# Empty DataFrame
# Columns: [Country, Country Code, Year, Sex, Suicide Rates/100k population, GDP_for_year ($) ]
# Index: []

# %%
dataCombine = dataCombine[["Country","Country Code","Year","Sex","Suicide Rates/100k population","GDP_for_year ($) "]]

# %%
dataCombine
# Out:
#                                                 Country Country Code  Year  \
# 0                                           Afghanistan          AFG  2000
# 1                                           Afghanistan          AFG  2000
# 2                                           Afghanistan          AFG  2000
# 3                                           Afghanistan          AFG  2010
# 4                                           Afghanistan          AFG  2010
# 5                                           Afghanistan          AFG  2010
# 6                                           Afghanistan          AFG  2015
# 7                                           Afghanistan          AFG  2015
# 8                                           Afghanistan          AFG  2015
# 9                                           Afghanistan          AFG  2016
# 10                                          Afghanistan          AFG  2016
# ...

# %%
dataCombine.to_csv("./dataCombineFinalfinal.csv")

# %% [markdown]
# # DATACHECKING(Check data outliers)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x=dataCombine['Year'],y=dataCombine['Suicide Rates/100k population'])

# %%
dataCombine2 = dataCombine[dataCombine.loc[:, 'Suicide Rates/100k population'] > 60]

# %%
dataCombine2
# Out:
#                  Country Country Code  Year   Sex  \
# 169              Belarus          BLR  2000  Male
# 1021          Kazakhstan          KAZ  2000  Male
# 1153           Lithuania          LTU  2000  Male
# 1621  Russian Federation          RUS  2000  Male
# 1624  Russian Federation          RUS  2010  Male
#
#       Suicide Rates/100k population GDP_for_year ($)
# 169                            70.4       1.27369e+10
# 1021                           63.1        1.8292e+10
# 1153                           81.7       1.15392e+10
# 1621                           85.8        2.5971e+11
# 1624                           62.3       1.52492e+12
