# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./WHOSuicideData.csv")

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 1  \
# 0        Country         Sex
# 1    Afghanistan  Both sexes
# 2    Afghanistan        Male
# 3    Afghanistan      Female
# 4        Albania  Both sexes
# ..           ...         ...
# 545       Zambia        Male
# 546       Zambia      Female
# 547     Zimbabwe  Both sexes
# 548     Zimbabwe        Male
# 549     Zimbabwe      Female
#
#      Age-standardized suicide rates (per 100 000 population)  \
# 0                                               2016.0
# 1                                                  6.4
# 2                                                 10.6
# 3                                                  2.1
# 4                                                  5.6
# ..                                                 ...
# 545                                               17.5
# 546                                                6.2
# 547                                               19.1
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0                                                    object
# Unnamed: 1                                                    object
# Age-standardized suicide rates (per 100 000 population)      float64
# Age-standardized suicide rates (per 100 000 population).1    float64
# Age-standardized suicide rates (per 100 000 population).2    float64
# Age-standardized suicide rates (per 100 000 population).3    float64
# dtype: object

# %%
data.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Age-standardized suicide rates (per 100 000 population)',
#  'Age-standardized suicide rates (per 100 000 population).1',
#  'Age-standardized suicide rates (per 100 000 population).2',
#  'Age-standardized suicide rates (per 100 000 population).3']

# %% [markdown]
# # Change the column name

# %%
data.rename(columns = {'Unnamed: 0' : 'Country','Unnamed: 1' : 'Sex'},inplace = True)

# %%
data.rename(columns = {'Age-standardized suicide rates (per 100 000 population)' : '2016','Age-standardized suicide rates (per 100 000 population).1' : '2015'},inplace = True)

# %%
data.rename(columns = {'Age-standardized suicide rates (per 100 000 population).2' : '2010','Age-standardized suicide rates (per 100 000 population).3' : '2000'},inplace = True)

# %%
data
# Out:
#          Country         Sex    2016    2015    2010    2000
# 0        Country         Sex  2016.0  2015.0  2010.0  2000.0
# 1    Afghanistan  Both sexes     6.4     6.6     7.4     8.1
# 2    Afghanistan        Male    10.6    10.9    12.5    14.3
# 3    Afghanistan      Female     2.1     2.1     2.1     1.7
# 4        Albania  Both sexes     5.6     5.3     7.7     5.8
# ..           ...         ...     ...     ...     ...     ...
# 545       Zambia        Male    17.5    17.4    17.9    21.9
# 546       Zambia      Female     6.2     6.1     6.2     7.5
# 547     Zimbabwe  Both sexes    19.1    18.9    20.6    21.7
# 548     Zimbabwe        Male    29.1    28.7    32.3    35.5
# 549     Zimbabwe      Female    11.1    11.1    11.1     9.8
#
# [550 rows x 6 columns]

# %% [markdown]
# # Delete the first row

# %%
data.columns.values.tolist()
# Out:
# ['Country', 'Sex', '2016', '2015', '2010', '2000']

# %%
data2 = data.drop([0], axis=0,inplace = True)

# %%
data2

# %% [markdown]
# # convert columns(2016,2015,2010,2000) into rows

# %%
dataNew = data.melt(id_vars=["Country", "Sex"], 
        var_name="Year", 
        value_name="Suicide Rates/100k population")

# %%
dataNew
# Out:
#           Country         Sex  Year  Suicide Rates/100k population
# 0     Afghanistan  Both sexes  2016                            6.4
# 1     Afghanistan        Male  2016                           10.6
# 2     Afghanistan      Female  2016                            2.1
# 3         Albania  Both sexes  2016                            5.6
# 4         Albania        Male  2016                            7.0
# ...           ...         ...   ...                            ...
# 2191       Zambia        Male  2000                           21.9
# 2192       Zambia      Female  2000                            7.5
# 2193     Zimbabwe  Both sexes  2000                           21.7
# 2194     Zimbabwe        Male  2000                           35.5
# 2195     Zimbabwe      Female  2000                            9.8
#
# [2196 rows x 4 columns]

# %% [markdown]
# # sort by column(Country and Year)

# %%
data = dataNew.sort_values(["Country", "Year"])

# %%
data
# Out:
#           Country         Sex  Year  Suicide Rates/100k population
# 1647  Afghanistan  Both sexes  2000                            8.1
# 1648  Afghanistan        Male  2000                           14.3
# 1649  Afghanistan      Female  2000                            1.7
# 1098  Afghanistan  Both sexes  2010                            7.4
# 1099  Afghanistan        Male  2010                           12.5
# ...           ...         ...   ...                            ...
# 1096     Zimbabwe        Male  2015                           28.7
# 1097     Zimbabwe      Female  2015                           11.1
# 546      Zimbabwe  Both sexes  2016                           19.1
# 547      Zimbabwe        Male  2016                           29.1
# 548      Zimbabwe      Female  2016                           11.1
#
# [2196 rows x 4 columns]

# %%
data.columns.values.tolist()
# Out:
# ['Country', 'Sex', 'Year', 'Suicide Rates/100k population']

# %%
data.head()
# Out:
#           Country         Sex  Year  Suicide Rates/100k population
# 1647  Afghanistan  Both sexes  2000                            8.1
# 1648  Afghanistan        Male  2000                           14.3
# 1649  Afghanistan      Female  2000                            1.7
# 1098  Afghanistan  Both sexes  2010                            7.4
# 1099  Afghanistan        Male  2010                           12.5

# %%
data
# Out:
#           Country         Sex  Year  Suicide Rates/100k population
# 1647  Afghanistan  Both sexes  2000                            8.1
# 1648  Afghanistan        Male  2000                           14.3
# 1649  Afghanistan      Female  2000                            1.7
# 1098  Afghanistan  Both sexes  2010                            7.4
# 1099  Afghanistan        Male  2010                           12.5
# ...           ...         ...   ...                            ...
# 1096     Zimbabwe        Male  2015                           28.7
# 1097     Zimbabwe      Female  2015                           11.1
# 546      Zimbabwe  Both sexes  2016                           19.1
# 547      Zimbabwe        Male  2016                           29.1
# 548      Zimbabwe      Female  2016                           11.1
#
# [2196 rows x 4 columns]

# %%
data = data[['Country', 'Year', 'Sex', 'Suicide Rates/100k population']]

# %%
data
# Out:
#           Country  Year         Sex  Suicide Rates/100k population
# 1647  Afghanistan  2000  Both sexes                            8.1
# 1648  Afghanistan  2000        Male                           14.3
# 1649  Afghanistan  2000      Female                            1.7
# 1098  Afghanistan  2010  Both sexes                            7.4
# 1099  Afghanistan  2010        Male                           12.5
# ...           ...   ...         ...                            ...
# 1096     Zimbabwe  2015        Male                           28.7
# 1097     Zimbabwe  2015      Female                           11.1
# 546      Zimbabwe  2016  Both sexes                           19.1
# 547      Zimbabwe  2016        Male                           29.1
# 548      Zimbabwe  2016      Female                           11.1
#
# [2196 rows x 4 columns]

# %%
data2 = pd.read_csv("./API_NY.GDP.MKTP.csv")

# %%
data2
# Out:
#            Data Source World Development Indicators         Unnamed: 2  \
# 0                  NaN                          NaN                NaN
# 1    Last Updated Date                    3/18/2020                NaN
# 2                  NaN                          NaN                NaN
# 3         Country Name                 Country Code     Indicator Name
# 4                Aruba                          ABW  GDP (current US$)
# ..                 ...                          ...                ...
# 263             Kosovo                          XKX  GDP (current US$)
# 264        Yemen, Rep.                          YEM  GDP (current US$)
# 265       South Africa                          ZAF  GDP (current US$)
# 266             Zambia                          ZMB  GDP (current US$)
# 267           Zimbabwe                          ZWE  GDP (current US$)
#
#          Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# ...

# %% [markdown]
# # Delete the row

# %%
data3 = data2.drop([0,1,2], axis=0,inplace = True)

# %%
data3

# %%
data2
# Out:
#       Data Source World Development Indicators         Unnamed: 2  \
# 3    Country Name                 Country Code     Indicator Name
# 4           Aruba                          ABW  GDP (current US$)
# 5     Afghanistan                          AFG  GDP (current US$)
# 6          Angola                          AGO  GDP (current US$)
# 7         Albania                          ALB  GDP (current US$)
# ..            ...                          ...                ...
# 263        Kosovo                          XKX  GDP (current US$)
# 264   Yemen, Rep.                          YEM  GDP (current US$)
# 265  South Africa                          ZAF  GDP (current US$)
# 266        Zambia                          ZMB  GDP (current US$)
# 267      Zimbabwe                          ZWE  GDP (current US$)
#
#          Unnamed: 3    Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# 3    Indicator Code  1.960000e+03  1.961000e+03  1.962000e+03  1.963000e+03
# ...

# %%
data2.drop(data2.iloc[:,5:7],1,inplace=True)

# %%
data2
# Out:
#       Data Source World Development Indicators         Unnamed: 2  \
# 3    Country Name                 Country Code     Indicator Name
# 4           Aruba                          ABW  GDP (current US$)
# 5     Afghanistan                          AFG  GDP (current US$)
# 6          Angola                          AGO  GDP (current US$)
# 7         Albania                          ALB  GDP (current US$)
# ..            ...                          ...                ...
# 263        Kosovo                          XKX  GDP (current US$)
# 264   Yemen, Rep.                          YEM  GDP (current US$)
# 265  South Africa                          ZAF  GDP (current US$)
# 266        Zambia                          ZMB  GDP (current US$)
# 267      Zimbabwe                          ZWE  GDP (current US$)
#
#          Unnamed: 3    Unnamed: 4    Unnamed: 7    Unnamed: 8    Unnamed: 9  \
# 3    Indicator Code  1.960000e+03  1.963000e+03  1.964000e+03  1.965000e+03
# ...

# %%
data2.drop(data2.iloc[:,4:53],1,inplace=True)

# %%
data2
# Out:
#       Data Source World Development Indicators         Unnamed: 2  \
# 3    Country Name                 Country Code     Indicator Name
# 4           Aruba                          ABW  GDP (current US$)
# 5     Afghanistan                          AFG  GDP (current US$)
# 6          Angola                          AGO  GDP (current US$)
# 7         Albania                          ALB  GDP (current US$)
# ..            ...                          ...                ...
# 263        Kosovo                          XKX  GDP (current US$)
# 264   Yemen, Rep.                          YEM  GDP (current US$)
# 265  South Africa                          ZAF  GDP (current US$)
# 266        Zambia                          ZMB  GDP (current US$)
# 267      Zimbabwe                          ZWE  GDP (current US$)
#
#          Unnamed: 3   Unnamed: 55   Unnamed: 56   Unnamed: 57   Unnamed: 58  \
# 3    Indicator Code  2.011000e+03  2.012000e+03  2.013000e+03  2.014000e+03
# ...

# %%
data2.rename(columns = {'Data Source' : 'Country','World Development Indicators' : 'Country Code'},inplace = True)

# %%
data2
# Out:
#           Country  Country Code         Unnamed: 2      Unnamed: 3  \
# 3    Country Name  Country Code     Indicator Name  Indicator Code
# 4           Aruba           ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 5     Afghanistan           AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 6          Angola           AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 7         Albania           ALB  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...           ...                ...             ...
# 263        Kosovo           XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 264   Yemen, Rep.           YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 265  South Africa           ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 266        Zambia           ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 267      Zimbabwe           ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#       Unnamed: 55   Unnamed: 56   Unnamed: 57   Unnamed: 58   Unnamed: 59  \
# 3    2.011000e+03  2.012000e+03  2.013000e+03  2.014000e+03  2.015000e+03
# ...

# %%
data2.rename(columns = {'Unnamed: 55' : '2011','Unnamed: 56' : '2012','Unnamed: 57' : '2013','Unnamed: 58' : '2014','Unnamed: 59' : '2015','Unnamed: 60' : '2016','Unnamed: 61' : '2017','Unnamed: 62' : '2018','Unnamed: 63' : '2019'},inplace = True)

# %%
data2
# Out:
#           Country  Country Code         Unnamed: 2      Unnamed: 3  \
# 3    Country Name  Country Code     Indicator Name  Indicator Code
# 4           Aruba           ABW  GDP (current US$)  NY.GDP.MKTP.CD
# 5     Afghanistan           AFG  GDP (current US$)  NY.GDP.MKTP.CD
# 6          Angola           AGO  GDP (current US$)  NY.GDP.MKTP.CD
# 7         Albania           ALB  GDP (current US$)  NY.GDP.MKTP.CD
# ..            ...           ...                ...             ...
# 263        Kosovo           XKX  GDP (current US$)  NY.GDP.MKTP.CD
# 264   Yemen, Rep.           YEM  GDP (current US$)  NY.GDP.MKTP.CD
# 265  South Africa           ZAF  GDP (current US$)  NY.GDP.MKTP.CD
# 266        Zambia           ZMB  GDP (current US$)  NY.GDP.MKTP.CD
# 267      Zimbabwe           ZWE  GDP (current US$)  NY.GDP.MKTP.CD
#
#              2011          2012          2013          2014          2015  \
# 3    2.011000e+03  2.012000e+03  2.013000e+03  2.014000e+03  2.015000e+03
# ...

# %%
data2.drop(data2[2:3],0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-c2f4d29b775a> in <module>
# ----> 1 data2.drop(data2[2:3],0,inplace=True)
#
# E:\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
data2.drop(['Unnamed: 2','Unnamed: 3'],1,inplace=True)

# %%
data2
# Out:
#           Country  Country Code          2011          2012          2013  \
# 3    Country Name  Country Code  2.011000e+03  2.012000e+03  2.013000e+03
# 4           Aruba           ABW  2.549721e+09  2.534637e+09  2.581564e+09
# 5     Afghanistan           AFG  1.780428e+10  2.000162e+10  2.056105e+10
# 6          Angola           AGO  1.117900e+11  1.280530e+11  1.367100e+11
# 7         Albania           ALB  1.289087e+10  1.231978e+10  1.277628e+10
# ..            ...           ...           ...           ...           ...
# 263        Kosovo           XKX  6.692431e+09  6.499760e+09  7.071982e+09
# 264   Yemen, Rep.           YEM  3.272642e+10  3.540134e+10  4.041523e+10
# 265  South Africa           ZAF  4.164190e+11  3.963330e+11  3.668290e+11
# 266        Zambia           ZMB  2.346010e+10  2.550337e+10  2.804546e+10
# 267      Zimbabwe           ZWE  1.410192e+10  1.711485e+10  1.909102e+10
#
#              2014          2015          2016          2017          2018  \
# ...

# %%
data3 = data2.drop([3], axis=0,inplace = True)

# %%
data2
# Out:
#           Country Country Code          2011          2012          2013  \
# 4           Aruba          ABW  2.549721e+09  2.534637e+09  2.581564e+09
# 5     Afghanistan          AFG  1.780428e+10  2.000162e+10  2.056105e+10
# 6          Angola          AGO  1.117900e+11  1.280530e+11  1.367100e+11
# 7         Albania          ALB  1.289087e+10  1.231978e+10  1.277628e+10
# 8         Andorra          AND  3.442063e+09  3.164615e+09  3.281585e+09
# ..            ...          ...           ...           ...           ...
# 263        Kosovo          XKX  6.692431e+09  6.499760e+09  7.071982e+09
# 264   Yemen, Rep.          YEM  3.272642e+10  3.540134e+10  4.041523e+10
# 265  South Africa          ZAF  4.164190e+11  3.963330e+11  3.668290e+11
# 266        Zambia          ZMB  2.346010e+10  2.550337e+10  2.804546e+10
# 267      Zimbabwe          ZWE  1.410192e+10  1.711485e+10  1.909102e+10
#
#              2014          2015          2016          2017          2018  \
# ...

# %%
dataNew2 = data2.melt(id_vars=["Country", "Country Code"], 
        var_name="Year", 
        value_name="GDP_for_year ($) ")

# %%
dataNew2
# Out:
#            Country Country Code  Year  GDP_for_year ($)
# 0            Aruba          ABW  2011       2.549721e+09
# 1      Afghanistan          AFG  2011       1.780428e+10
# 2           Angola          AGO  2011       1.117900e+11
# 3          Albania          ALB  2011       1.289087e+10
# 4          Andorra          AND  2011       3.442063e+09
# ...            ...          ...   ...                ...
# 2371        Kosovo          XKX  2019                NaN
# 2372   Yemen, Rep.          YEM  2019                NaN
# 2373  South Africa          ZAF  2019                NaN
# 2374        Zambia          ZMB  2019                NaN
# 2375      Zimbabwe          ZWE  2019                NaN
#
# [2376 rows x 4 columns]

# %%
data2 = dataNew2.sort_values(["Country", "Year"])

# %%
data2
# Out:
#           Country Country Code  Year  GDP_for_year ($)
# 1     Afghanistan          AFG  2011       1.780428e+10
# 265   Afghanistan          AFG  2012       2.000162e+10
# 529   Afghanistan          AFG  2013       2.056105e+10
# 793   Afghanistan          AFG  2014       2.048487e+10
# 1057  Afghanistan          AFG  2015       1.990711e+10
# ...           ...          ...   ...                ...
# 1319     Zimbabwe          ZWE  2015       1.996312e+10
# 1583     Zimbabwe          ZWE  2016       2.054868e+10
# 1847     Zimbabwe          ZWE  2017       2.281301e+10
# 2111     Zimbabwe          ZWE  2018       3.100052e+10
# 2375     Zimbabwe          ZWE  2019                NaN
#
# [2376 rows x 4 columns]

# %%
data1.dtypes
# Out:
# Country                           object
# Sex                               object
# Year                              object
# Suicide Rates/100k population    float64
# dtype: object

# %%
data2.dtypes
# Out:
# Country               object
# Country Code          object
# Year                  object
# GDP_for_year ($)     float64
# dtype: object

# %% [markdown]
# # Combine two DataFrames using Year

# %%
import difflib

# %%
difflib.get_close_matches
# Out:
# <function difflib.get_close_matches(word, possibilities, n=3, cutoff=0.6)>

# %%
data7 = pd.merge(data,data2,how = "left", on = ["Country","Year"])

# %%
data7
# Out:
#           Country  Year         Sex  Suicide Rates/100k population  \
# 0     Afghanistan  2000  Both sexes                            8.1
# 1     Afghanistan  2000        Male                           14.3
# 2     Afghanistan  2000      Female                            1.7
# 3     Afghanistan  2010  Both sexes                            7.4
# 4     Afghanistan  2010        Male                           12.5
# ...           ...   ...         ...                            ...
# 2191     Zimbabwe  2015        Male                           28.7
# 2192     Zimbabwe  2015      Female                           11.1
# 2193     Zimbabwe  2016  Both sexes                           19.1
# 2194     Zimbabwe  2016        Male                           29.1
# 2195     Zimbabwe  2016      Female                           11.1
#
#      Country Code  GDP_for_year ($)
# 0             NaN                NaN
# 1             NaN                NaN
# 2             NaN                NaN
# ...

# %%
data7.isnull().sum().sort_values(ascending = False)
# Out:
# GDP_for_year ($)                 1263
# Country Code                     1248
# Suicide Rates/100k population       0
# Sex                                 0
# Year                                0
# Country                             0
# dtype: int64

# %%
data7.to_csv("./cleanData7.csv")

# %%
data.to_csv("./cleanData1.csv")

# %%
data2.to_csv("./cleanData2.csv")
